# %% [markdown]
# ## read_EGHS_pdf
#
# E. Quinn 1/1/2020
#
# This notebook uses pdfminer to extract the information from the EGHS budget pdf
#
# The documentation for pdfminer is at:
#
# https://buildmedia.readthedocs.org/media/pdf/pdfminer-docs/latest/pdfminer-docs.pdf

# %% [markdown]
# ## Import standard python datascience packages

# %%
import math
import re
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from datetime import *
from datascience import *

# %% [markdown]
# ## Import pdfminer packages

# %%
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfpage import PDFTextExtractionNotAllowed
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfdevice import PDFDevice
from pdfminer.layout import LAParams
from pdfminer.converter import PDFPageAggregator
from pdfminer.pdfpage import PDFPage
from pdfminer.layout import LTTextBoxHorizontal

# %%
pd.set_option("display.max_rows",1000)
pd.get_option("display.max_rows")
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### Show the directory we are running in

# %%
# !pwd
# Out:
# /home/gquinn/EG/school_committee/finance_subcommittee/notebooks

# %% [markdown]
# ## Read the pdf and create a dictionary with the contents of each text box

# %% [markdown]
# ### Function read_earnings() reads the earnings report and returns a dictionary containing the contents
#
# Strategy for this document:
#
# Save information from each element in the LTTextBox objects in a dictionary including:
#
# - x0 horizontal coordinate of the upper left corner of the text box
# - x1 horizontal coordinate of the lower right corner of the text box
# - y0 vertical coordinate of the upper left corner of the text box
# - y1 vertical coordinate of the lower right corner of the text box
# - page number
# - sequence number of text box within this page
# - text contained in the text box, converted to ascii
#
# Parsing the text is complicated by the fact that that a text box may span multiple columns and/or rows, and the text box groupings vary quite a bit depending on the page contents and layout.
#
# However, with a bit of luck the structure of the document will allow the contents to be deciphered with the following heuristics:
#
# - Text boxes containing left justified columns will tend to have nearly the same x0 coordinates
# - Text boxes containing right justified columns will tend to have nearly the same x1 coordinates
# - The codes for fund, account code, and object code are numeric and have fixed lengths
# - Extraneous information is often preceded or followed by a series of underscore and newline characters
# - Last name can be distinguished because is the only field that is all characters followed by a comma
# - Last name may be preceded by between one and three numerical fields:  fund, account, object.  If it is, the x0 value is shifted to the left.
#     - Three numerical fields precede the name:  assume they are fund, account, object
#     - Two numerical fields precede the name: assume they are account, object
#     - One numerical field precedes the name: assume it is object

# %%
def read_pdf(path):
    document = open(path, 'rb')                                     #read a pdf and create a document object
    rsrcmgr = PDFResourceManager()                                  #create a resource manager
    laparams = LAParams()                                           #set the parameters for analysis
    device = PDFPageAggregator(rsrcmgr, laparams=laparams)          #create a PDF page aggregator object
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    
    pdf={}                                                          #dictionary to hold the results

    pageno = -1                                                     #initialize page coounter to zero

    for page in PDFPage.get_pages(document):                        #loop through the pdf page by page
        pageno = pageno + 1                                         #increment the page number
        pdf[pageno] = {}                                            #dictionary for this page
        interpreter.process_page(page)                              # receive the LTPage object for the page.
        layout = device.get_result()                                # create layout object
        tbox_no=0                                                   # index for element number
        for element in layout:
            if (type(element).__name__=='LTTextBoxHorizontal'):     #loop through text boxes
                tbox_no += 1                                        #increment text box number
                pdf[pageno][tbox_no] = {}                           #dictionary for text boxes within page
                x0 = round(element.x0,2)                            #x0 coordinate of textbox corner
                x1 = round(element.x1,2)                            #x1 coordinate of textbox corner
                y0 = round(element.y0,2)                            #y0 coordinate of textbox corner
                y1 = round(element.y1,2)                            #y1 coordinate of textbox corner
                txt = element.get_text().encode('ascii', 'ignore')  #text converted to ascii
                pdf[pageno][tbox_no]['x0'] = x0                     #create x0 coordinate entry
                pdf[pageno][tbox_no]['x1'] = x1                     #create x1 coordinate entry
                pdf[pageno][tbox_no]['y0'] = y0                     #create y0 coordinate entry
                pdf[pageno][tbox_no]['y1'] = y1                     #create y1 coordinate entry

                pdf[pageno][tbox_no]['text'] = ''.join(chr(c) for c in txt) #convert bytes to string
    return(pdf)

# %%
def get_lineitems(pdf):

    lineitems = {}

    for page in pdf.keys():
        for tb in pdf[page].keys():
            if (pdf[page][tb]['x0']==31.0):
                text = pdf[page][tb]['text']
                lines = text.split('\n')
                if (text.count('-')>=4):
                    if (page not in lineitems.keys()):
                        lineitems[page] = {}
                    if (tb not in lineitems[page].keys()):
                        lineitems[page][tb] = {}
                    lineitems[page][tb]['x0'] = pdf[page][tb]['x0'] 
                    lineitems[page][tb]['x1'] = pdf[page][tb]['x1']
                    lineitems[page][tb]['y0'] = pdf[page][tb]['y0']
                    lineitems[page][tb]['y1'] = pdf[page][tb]['y1']
                    lineitems[page][tb]['text'] = pdf[page][tb]['text']
    return(lineitems)

# %%
def find_matches(pg,minx0,maxx0,y0in,y1in,tolerance):
    dct = {}
    for tbx in pg.keys():
        tx0 = pg[tbx]['x0']
        tx1 = pg[tbx]['x1']
        if ((minx0 < tx0) & (tx0 < maxx0)):
            ty0 = pg[tbx]['y0']
            ty1 = pg[tbx]['y1']
            txt = pg[tbx]['text']
            if ((y0in-tolerance < ty0) & (ty1 < y1in+tolerance)):
                dct[ty1] = txt
    dct2 = {}
    seq = 0
    if (len(dct) > 0):
        for y in sorted(dct.keys()):
                    lines = dct[y].split('\n')
                    for line in reversed(lines):
                        if (len(line) > 0):
                            if (len(line)==1):
                                dct2[seq] = '0.0'
                            else:
                                dct2[seq] = line
                            seq = seq+1
    dct3 = {}
    l2 = len(dct2)
    for seq in dct2.keys():
        dct3[l2-seq] = dct2[seq]
    return(dct3)

# %%
def budget_dct(lid,bd_old):
    bd = {}
    bd_index = len(bd_old.keys()) + 1
    for page in lid.keys():
        for tb in lid[page].keys():
            if ('text' in lid[page][tb].keys()):
                txt = lid[page][tb]['text']
                lines = txt.split('\n')
                tb_index = 1
                for line in lines:
                    if (line.count('-') > 1):
                        bd[bd_index] = {}
                        bd[bd_index]['ucoa'] = line
                        words = line.split('-')
                        bd[bd_index]['Fund'] = float(words[0].strip() + '0000')                                                 
                        bd[bd_index]['Loc'] = float(words[1])   
                        bd[bd_index]['Func'] = float(words[2]) 
                        bd[bd_index]['Prog'] = float(words[3]) 
                        bd[bd_index]['Sub'] = float(words[4])
                        bd[bd_index]['JC'] = float(words[5])
                        acct_string = lid[page][tb]['acct-code'][tb_index]
                        acct_desc = acct_string[acct_string.index(' ',acct_string.index(' ')+1):].strip()
                        bd[bd_index]['acct-string'] = lid[page][tb]['acct-code'][tb_index]
                        bd[bd_index]['acct-desc'] = acct_desc
                        words = acct_string.split()
                        bd[bd_index]['acct-code'] = words[0]
                        bd[bd_index]['Obj'] = float(words[1])
                        bd[bd_index]['budget2020'] = float(lid[page][tb]['budget2020'][tb_index].replace(',',''))
                        bd[bd_index]['budget2019'] = float(lid[page][tb]['budget2019'][tb_index].replace(',',''))
                        bd[bd_index]['actual2018'] = float(lid[page][tb]['actual2018'][tb_index].replace(',',''))
                        bd[bd_index]['actual2017'] = float(lid[page][tb]['actual2017'][tb_index].replace(',',''))
                        bd_index += 1
                        tb_index += 1
    return(bd)

# %% [markdown]
# ### Read the PDF

# %%
pdfd = read_pdf('../EGHS FY20Budget.pdf')

# %%
lineitems = get_lineitems(pdfd)

# %%
for page in lineitems.keys():
    pg = lineitems[page]
    for tb in pg.keys():
        x0 = pg[tb]['x0']
        x1 = pg[tb]['x1']
        y0 = pg[tb]['y0']
        y1 = pg[tb]['y1']
        text = pg[tb]['text']
        pg[tb]['budget2019'] = find_matches(pdfd[page],525.0,570.0,y0,y1,5)
        pg[tb]['budget2020'] = find_matches(pdfd[page],650.0,705.0,y0,y1,5)
        pg[tb]['actual2018'] = find_matches(pdfd[page],450.0,505.0,y0,y1,5)
        pg[tb]['actual2017'] = find_matches(pdfd[page],395.0,445.0,y0,y1,5)
        pg[tb]['acct-code']  = find_matches(pdfd[page],195.0,385.0,y0,y1,5)

# %%
bd_old = {}
bd = budget_dct(lineitems,bd_old)

# %%
bd
# Out:
# {1: {'ucoa': '1000 - 05106 - 00222 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71289006 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71289006',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 3150.0,
#   'actual2018': 853.12,
#   'actual2017': 7925.49},
#  2: {'ucoa': '1000 - 05106 - 00222 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71289006 53303 Conf/Workshops',
#   'acct-desc': 'Conf/Workshops',
#   'acct-code': '71289006',
#   'Obj': 53303.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 379.98,
#   'actual2017': 0.0},
#  3: {'ucoa': '1000 - 05106 - 00511 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 511.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71400006 53303 Conferences',
#   'acct-desc': 'Conferences',
#   'acct-code': '71400006',
#   'Obj': 53303.0,
#   'budget2020': 4000.0,
#   'budget2019': 4400.0,
#   'actual2018': 1000.0,
#   'actual2017': 0.0},
#  4: {'ucoa': '1000 - 05106 - 00512 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 512.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71410006 53406 Other Services',
#   'acct-desc': 'Other Services',
#   'acct-code': '71410006',
#   'Obj': 53406.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 245.7,
#   'actual2017': 307.99},
#  5: {'ucoa': '1000 - 05106 - 00214 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 214.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71269006 53502 Other Tech. Services',
#   'acct-desc': 'Other Tech. Services',
#   'acct-code': '71269006',
#   'Obj': 53502.0,
#   'budget2020': 13000.0,
#   'budget2019': 13011.0,
#   'actual2018': 12386.1,
#   'actual2017': 0.0},
#  6: {'ucoa': '1000 - 05106 - 00512 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 512.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71410006 53705 Shippingpostage',
#   'acct-desc': 'Shippingpostage',
#   'acct-code': '71410006',
#   'Obj': 53705.0,
#   'budget2020': 200.0,
#   'budget2019': 186.0,
#   'actual2018': 181.72,
#   'actual2017': 300.0},
#  7: {'ucoa': '1000 - 05106 - 00512 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 512.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71410006 55501 Printing',
#   'acct-desc': 'Printing',
#   'acct-code': '71410006',
#   'Obj': 55501.0,
#   'budget2020': 1500.0,
#   'budget2019': 1245.0,
#   'actual2018': 835.2,
#   'actual2017': 1499.38},
#  8: {'ucoa': '1000 - 05106 - 00512 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 512.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71410006 55503 Document Copying',
#   'acct-desc': 'Document Copying',
#   'acct-code': '71410006',
#   'Obj': 55503.0,
#   'budget2020': 22000.0,
#   'budget2019': 3950.0,
#   'actual2018': 22209.78,
#   'actual2017': 35174.96},
#  9: {'ucoa': '1000 - 05106 - 00511 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 511.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71400006 56101 Office Supplies',
#   'acct-desc': 'Office Supplies',
#   'acct-code': '71400006',
#   'Obj': 56101.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 610.3,
#   'actual2017': 0.0},
#  10: {'ucoa': '1000 - 05106 - 00512 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 512.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71410006 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71410006',
#   'Obj': 56101.0,
#   'budget2020': 9500.0,
#   'budget2019': 9521.8,
#   'actual2018': 7453.08,
#   'actual2017': 6233.69},
#  11: {'ucoa': '1000 - 05106 - 00512 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 512.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71410006 56112 Uniform Supplies',
#   'acct-desc': 'Uniform Supplies',
#   'acct-code': '71410006',
#   'Obj': 56112.0,
#   'budget2020': 0.0,
#   'budget2019': 3500.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  12: {'ucoa': '1000 - 05106 - 00214 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 214.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71269006 56113 Graduation Supplies',
#   'acct-desc': 'Graduation Supplies',
#   'acct-code': '71269006',
#   'Obj': 56113.0,
#   'budget2020': 12000.0,
#   'budget2019': 11000.0,
#   'actual2018': 12129.2,
#   'actual2017': 11107.16},
#  13: {'ucoa': '1000 - 05106 - 00512 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 512.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71410006 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71410006',
#   'Obj': 57305.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 0.0,
#   'actual2017': 1027.99},
#  14: {'ucoa': '1000 - 05106 - 00512 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 512.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71410006 57306 Furniture & Fixtures',
#   'acct-desc': 'Furniture & Fixtures',
#   'acct-code': '71410006',
#   'Obj': 57306.0,
#   'budget2020': 2500.0,
#   'budget2019': 2463.2,
#   'actual2018': 0.0,
#   'actual2017': 1048.64},
#  15: {'ucoa': '1000 - 05106 - 00511 - 10 - 0000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 511.0,
#   'Prog': 10.0,
#   'Sub': 0.0,
#   'JC': 0.0,
#   'acct-string': '71400006 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71400006',
#   'Obj': 58102.0,
#   'budget2020': 5500.0,
#   'budget2019': 5455.0,
#   'actual2018': 4855.0,
#   'actual2017': 4725.0},
#  16: {'ucoa': '1000 - 05106 - 00222 - 10 - 0200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 200.0,
#   'JC': 0.0,
#   'acct-string': '71443606 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71443606',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 255.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  17: {'ucoa': '1000 - 05106 - 00122 - 10 - 0200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 200.0,
#   'JC': 0.0,
#   'acct-string': '71432106 54311 Maint-Fixturesequip',
#   'acct-desc': 'Maint-Fixturesequip',
#   'acct-code': '71432106',
#   'Obj': 54311.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 570.4,
#   'actual2017': 468.25},
#  18: {'ucoa': '1000 - 05106 - 00122 - 10 - 0200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 200.0,
#   'JC': 0.0,
#   'acct-string': '71432106 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71432106',
#   'Obj': 56101.0,
#   'budget2020': 13000.0,
#   'budget2019': 12630.67,
#   'actual2018': 12931.59,
#   'actual2017': 12475.92},
#  19: {'ucoa': '1000 - 05106 - 00122 - 10 - 0200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 200.0,
#   'JC': 0.0,
#   'acct-string': '71432106 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71432106',
#   'Obj': 57305.0,
#   'budget2020': 0.0,
#   'budget2019': 1024.63,
#   'actual2018': 0.0,
#   'actual2017': 2938.0},
#  20: {'ucoa': '1000 - 05106 - 00122 - 10 - 0200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 200.0,
#   'JC': 0.0,
#   'acct-string': '71432106 57306 Furniture & Fixtures',
#   'acct-desc': 'Furniture & Fixtures',
#   'acct-code': '71432106',
#   'Obj': 57306.0,
#   'budget2020': 3200.0,
#   'budget2019': 3124.7,
#   'actual2018': 3205.5,
#   'actual2017': 0.0},
#  21: {'ucoa': '1000 - 05106 - 00122 - 10 - 0200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 200.0,
#   'JC': 0.0,
#   'acct-string': '71432106 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71432106',
#   'Obj': 58102.0,
#   'budget2020': 420.0,
#   'budget2019': 285.0,
#   'actual2018': 405.0,
#   'actual2017': 285.0},
#  22: {'ucoa': '1000 - 05106 - 00222 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71441406 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71441406',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 528.0,
#   'actual2018': 145.0,
#   'actual2017': 119.0},
#  23: {'ucoa': '1000 - 05106 - 00222 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71441406 53303 Conf/Workshops',
#   'acct-desc': 'Conf/Workshops',
#   'acct-code': '71441406',
#   'Obj': 53303.0,
#   'budget2020': 0.0,
#   'budget2019': 240.0,
#   'actual2018': 0.0,
#   'actual2017': 28.0},
#  24: {'ucoa': '1000 - 05106 - 00122 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71432306 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71432306',
#   'Obj': 55809.0,
#   'budget2020': 300.0,
#   'budget2019': 300.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  25: {'ucoa': '1000 - 05106 - 00222 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71441406 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71441406',
#   'Obj': 55809.0,
#   'budget2020': 300.0,
#   'budget2019': 378.76,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  26: {'ucoa': '1000 - 05106 - 00122 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71432306 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71432306',
#   'Obj': 56101.0,
#   'budget2020': 900.0,
#   'budget2019': 900.0,
#   'actual2018': 899.03,
#   'actual2017': 405.53},
#  27: {'ucoa': '1000 - 05106 - 00122 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71432306 56401 Textbooks',
#   'acct-desc': 'Textbooks',
#   'acct-code': '71432306',
#   'Obj': 56401.0,
#   'budget2020': 5670.0,
#   'budget2019': 5670.0,
#   'actual2018': 5992.96,
#   'actual2017': 2987.89},
#  28: {'ucoa': '1000 - 05106 - 00122 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71432306 56501 Software Supplies',
#   'acct-desc': 'Software Supplies',
#   'acct-code': '71432306',
#   'Obj': 56501.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 0.0,
#   'actual2017': 97.97},
#  29: {'ucoa': '1000 - 05106 - 00122 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71432306 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71432306',
#   'Obj': 57305.0,
#   'budget2020': 35.0,
#   'budget2019': 35.0,
#   'actual2018': 48.93,
#   'actual2017': 1049.85},
#  30: {'ucoa': '1000 - 05106 - 00122 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71432306 57306 Furniture & Fixtures',
#   'acct-desc': 'Furniture & Fixtures',
#   'acct-code': '71432306',
#   'Obj': 57306.0,
#   'budget2020': 2165.0,
#   'budget2019': 2165.0,
#   'actual2018': 2148.55,
#   'actual2017': 0.0},
#  31: {'ucoa': '1000 - 05106 - 00122 - 10 - 0500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 500.0,
#   'JC': 0.0,
#   'acct-string': '71432306 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71432306',
#   'Obj': 58102.0,
#   'budget2020': 0.0,
#   'budget2019': 200.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  32: {'ucoa': '1000 - 05106 - 00222 - 10 - 0700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 700.0,
#   'JC': 0.0,
#   'acct-string': '71441606 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71441606',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 932.0,
#   'actual2018': 0.0,
#   'actual2017': 414.43},
#  33: {'ucoa': '1000 - 05106 - 00122 - 10 - 0700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 700.0,
#   'JC': 0.0,
#   'acct-string': '71432406 55111 Transportation',
#   'acct-desc': 'Transportation',
#   'acct-code': '71432406',
#   'Obj': 55111.0,
#   'budget2020': 750.0,
#   'budget2019': 1040.0,
#   'actual2018': 313.85,
#   'actual2017': 0.0},
#  34: {'ucoa': '1000 - 05106 - 00122 - 10 - 0700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 700.0,
#   'JC': 0.0,
#   'acct-string': '71432406 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71432406',
#   'Obj': 55809.0,
#   'budget2020': 200.0,
#   'budget2019': 300.0,
#   'actual2018': 132.0,
#   'actual2017': 0.0},
#  35: {'ucoa': '1000 - 05106 - 00222 - 10 - 0700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 700.0,
#   'JC': 0.0,
#   'acct-string': '71441606 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71441606',
#   'Obj': 55809.0,
#   'budget2020': 200.0,
#   'budget2019': 464.16,
#   'actual2018': 0.0,
#   'actual2017': 348.65},
#  36: {'ucoa': '1000 - 05106 - 00122 - 10 - 0700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 700.0,
#   'JC': 0.0,
#   'acct-string': '71432406 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71432406',
#   'Obj': 56101.0,
#   'budget2020': 1500.0,
#   'budget2019': 1575.0,
#   'actual2018': 644.97,
#   'actual2017': 895.45},
#  37: {'ucoa': '1000 - 05106 - 00122 - 10 - 0700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 700.0,
#   'JC': 0.0,
#   'acct-string': '71432406 56401 Textbooks',
#   'acct-desc': 'Textbooks',
#   'acct-code': '71432406',
#   'Obj': 56401.0,
#   'budget2020': 1500.0,
#   'budget2019': 2500.0,
#   'actual2018': 593.01,
#   'actual2017': 626.5},
#  38: {'ucoa': '1000 - 05106 - 00122 - 10 - 0700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 700.0,
#   'JC': 0.0,
#   'acct-string': '71432406 56404 Subscriptions/Periodicals',
#   'acct-desc': 'Subscriptions/Periodicals',
#   'acct-code': '71432406',
#   'Obj': 56404.0,
#   'budget2020': 170.0,
#   'budget2019': 170.0,
#   'actual2018': 0.0,
#   'actual2017': 86.98},
#  39: {'ucoa': '1000 - 05106 - 00122 - 10 - 0700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 700.0,
#   'JC': 0.0,
#   'acct-string': '71432406 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71432406',
#   'Obj': 57305.0,
#   'budget2020': 5800.0,
#   'budget2019': 5800.0,
#   'actual2018': 603.04,
#   'actual2017': 0.0},
#  40: {'ucoa': '1000 - 05106 - 00122 - 10 - 0700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 700.0,
#   'JC': 0.0,
#   'acct-string': '71432406 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71432406',
#   'Obj': 58102.0,
#   'budget2020': 700.0,
#   'budget2019': 700.0,
#   'actual2018': 660.0,
#   'actual2017': 720.0},
#  41: {'ucoa': '1000 - 05106 - 00222 - 10 - 0800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 800.0,
#   'JC': 0.0,
#   'acct-string': '71443706 53303 Conf/Workshops',
#   'acct-desc': 'Conf/Workshops',
#   'acct-code': '71443706',
#   'Obj': 53303.0,
#   'budget2020': 0.0,
#   'budget2019': 340.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  42: {'ucoa': '1000 - 05106 - 00211 - 10 - 0800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 211.0,
#   'Prog': 10.0,
#   'Sub': 800.0,
#   'JC': 0.0,
#   'acct-string': '71231406 53503 Testing',
#   'acct-desc': 'Testing',
#   'acct-code': '71231406',
#   'Obj': 53503.0,
#   'budget2020': 12000.0,
#   'budget2019': 5400.0,
#   'actual2018': 2556.97,
#   'actual2017': 3606.0},
#  43: {'ucoa': '1000 - 05106 - 00211 - 10 - 0800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 211.0,
#   'Prog': 10.0,
#   'Sub': 800.0,
#   'JC': 0.0,
#   'acct-string': '71231406 53705 Shippingpostage',
#   'acct-desc': 'Shippingpostage',
#   'acct-code': '71231406',
#   'Obj': 53705.0,
#   'budget2020': 0.0,
#   'budget2019': 100.0,
#   'actual2018': 0.0,
#   'actual2017': 325.0},
#  44: {'ucoa': '1000 - 05106 - 00122 - 10 - 0800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 800.0,
#   'JC': 0.0,
#   'acct-string': '71432006 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71432006',
#   'Obj': 55809.0,
#   'budget2020': 0.0,
#   'budget2019': 200.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  45: {'ucoa': '1000 - 05106 - 00211 - 10 - 0800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 211.0,
#   'Prog': 10.0,
#   'Sub': 800.0,
#   'JC': 0.0,
#   'acct-string': '71231406 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71231406',
#   'Obj': 56101.0,
#   'budget2020': 1200.0,
#   'budget2019': 1268.0,
#   'actual2018': 1119.77,
#   'actual2017': 1124.91},
#  46: {'ucoa': '1000 - 05106 - 00211 - 10 - 0800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 211.0,
#   'Prog': 10.0,
#   'Sub': 800.0,
#   'JC': 0.0,
#   'acct-string': '71231406 56403 Reference Books',
#   'acct-desc': 'Reference Books',
#   'acct-code': '71231406',
#   'Obj': 56403.0,
#   'budget2020': 400.0,
#   'budget2019': 406.0,
#   'actual2018': 506.63,
#   'actual2017': 0.0},
#  47: {'ucoa': '1000 - 05106 - 00211 - 10 - 0800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 211.0,
#   'Prog': 10.0,
#   'Sub': 800.0,
#   'JC': 0.0,
#   'acct-string': '71231406 58102 Other Dues And Fees',
#   'acct-desc': 'Other Dues And Fees',
#   'acct-code': '71231406',
#   'Obj': 58102.0,
#   'budget2020': 900.0,
#   'budget2019': 925.0,
#   'actual2018': 718.54,
#   'actual2017': 739.35},
#  48: {'ucoa': '1000 - 05106 - 00222 - 10 - 1200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1200.0,
#   'JC': 0.0,
#   'acct-string': '71442806 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71442806',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 420.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  49: {'ucoa': '1000 - 05106 - 00222 - 10 - 1200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1200.0,
#   'JC': 0.0,
#   'acct-string': '71442806 53303 Conf/Workshops',
#   'acct-desc': 'Conf/Workshops',
#   'acct-code': '71442806',
#   'Obj': 53303.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 87.43,
#   'actual2017': 0.0},
#  50: {'ucoa': '1000 - 05106 - 00122 - 10 - 1200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1200.0,
#   'JC': 0.0,
#   'acct-string': '71432506 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71432506',
#   'Obj': 55809.0,
#   'budget2020': 0.0,
#   'budget2019': 300.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  51: {'ucoa': '1000 - 05106 - 00122 - 10 - 1200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1200.0,
#   'JC': 0.0,
#   'acct-string': '71432506 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71432506',
#   'Obj': 56101.0,
#   'budget2020': 2200.0,
#   'budget2019': 2213.0,
#   'actual2018': 2022.19,
#   'actual2017': 2373.91},
#  52: {'ucoa': '1000 - 05106 - 00122 - 10 - 1200 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1200.0,
#   'JC': 0.0,
#   'acct-string': '71432506 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71432506',
#   'Obj': 58102.0,
#   'budget2020': 0.0,
#   'budget2019': 100.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  53: {'ucoa': '1000 - 05106 - 00222 - 10 - 1413 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1413.0,
#   'JC': 0.0,
#   'acct-string': '71443106 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71443106',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 570.0,
#   'actual2018': 0.0,
#   'actual2017': 359.88},
#  54: {'ucoa': '1000 - 05106 - 00222 - 10 - 1413 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1413.0,
#   'JC': 0.0,
#   'acct-string': '71443106 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71443106',
#   'Obj': 55809.0,
#   'budget2020': 0.0,
#   'budget2019': 30.0,
#   'actual2018': 0.0,
#   'actual2017': 30.0},
#  55: {'ucoa': '1000 - 05106 - 00122 - 10 - 1800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1800.0,
#   'JC': 0.0,
#   'acct-string': '71433206 55111 Transportation',
#   'acct-desc': 'Transportation',
#   'acct-code': '71433206',
#   'Obj': 55111.0,
#   'budget2020': 2000.0,
#   'budget2019': 2020.0,
#   'actual2018': 2397.93,
#   'actual2017': 2425.0},
#  56: {'ucoa': '1000 - 05106 - 00122 - 10 - 1800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1800.0,
#   'JC': 0.0,
#   'acct-string': '71433206 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71433206',
#   'Obj': 56101.0,
#   'budget2020': 1200.0,
#   'budget2019': 1230.0,
#   'actual2018': 1049.06,
#   'actual2017': 152.13},
#  57: {'ucoa': '1000 - 05106 - 00122 - 10 - 1800 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1800.0,
#   'JC': 0.0,
#   'acct-string': '71433206 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71433206',
#   'Obj': 58102.0,
#   'budget2020': 0.0,
#   'budget2019': 100.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  58: {'ucoa': '1000 - 05106 - 00222 - 10 - 1500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1500.0,
#   'JC': 0.0,
#   'acct-string': '71441706 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71441706',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 1033.48,
#   'actual2018': 0.0,
#   'actual2017': 4800.0},
#  59: {'ucoa': '1000 - 05106 - 00222 - 10 - 1500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1500.0,
#   'JC': 0.0,
#   'acct-string': '71441706 53303 Conf/Workshops',
#   'acct-desc': 'Conf/Workshops',
#   'acct-code': '71441706',
#   'Obj': 53303.0,
#   'budget2020': 240.0,
#   'budget2019': 240.0,
#   'actual2018': 247.96,
#   'actual2017': 0.0},
#  60: {'ucoa': '1000 - 05106 - 00122 - 10 - 1500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1500.0,
#   'JC': 0.0,
#   'acct-string': '71432706 55111 Transportation',
#   'acct-desc': 'Transportation',
#   'acct-code': '71432706',
#   'Obj': 55111.0,
#   'budget2020': 1500.0,
#   'budget2019': 2365.0,
#   'actual2018': 552.19,
#   'actual2017': 821.0},
#  61: {'ucoa': '1000 - 05106 - 00122 - 10 - 1500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1500.0,
#   'JC': 0.0,
#   'acct-string': '71432706 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71432706',
#   'Obj': 55809.0,
#   'budget2020': 0.0,
#   'budget2019': 300.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  62: {'ucoa': '1000 - 05106 - 00222 - 10 - 1500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1500.0,
#   'JC': 0.0,
#   'acct-string': '71441706 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71441706',
#   'Obj': 55809.0,
#   'budget2020': 126.52,
#   'budget2019': 126.52,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  63: {'ucoa': '1000 - 05106 - 00122 - 10 - 1500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1500.0,
#   'JC': 0.0,
#   'acct-string': '71432706 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71432706',
#   'Obj': 56101.0,
#   'budget2020': 2250.0,
#   'budget2019': 2250.0,
#   'actual2018': 2261.1,
#   'actual2017': 2992.3},
#  64: {'ucoa': '1000 - 05106 - 00122 - 10 - 1500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1500.0,
#   'JC': 0.0,
#   'acct-string': '71432706 56401 Textbooks',
#   'acct-desc': 'Textbooks',
#   'acct-code': '71432706',
#   'Obj': 56401.0,
#   'budget2020': 4500.0,
#   'budget2019': 4500.0,
#   'actual2018': 1024.22,
#   'actual2017': 11135.16},
#  65: {'ucoa': '1000 - 05106 - 00122 - 10 - 1500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1500.0,
#   'JC': 0.0,
#   'acct-string': '71432706 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71432706',
#   'Obj': 57305.0,
#   'budget2020': 0.0,
#   'budget2019': 500.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  66: {'ucoa': '1000 - 05106 - 00122 - 10 - 1500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1500.0,
#   'JC': 0.0,
#   'acct-string': '71432706 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71432706',
#   'Obj': 58102.0,
#   'budget2020': 710.0,
#   'budget2019': 710.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  67: {'ucoa': '1000 - 05106 - 00111 - 10 - 1600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 111.0,
#   'Prog': 10.0,
#   'Sub': 1600.0,
#   'JC': 0.0,
#   'acct-string': '71128006 53210 Performing Arts',
#   'acct-desc': 'Performing Arts',
#   'acct-code': '71128006',
#   'Obj': 53210.0,
#   'budget2020': 450.0,
#   'budget2019': 450.0,
#   'actual2018': 0.0,
#   'actual2017': 435.0},
#  68: {'ucoa': '1000 - 05106 - 00122 - 10 - 1600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1600.0,
#   'JC': 0.0,
#   'acct-string': '71432806 54311 Maint-Fixturesequip',
#   'acct-desc': 'Maint-Fixturesequip',
#   'acct-code': '71432806',
#   'Obj': 54311.0,
#   'budget2020': 600.0,
#   'budget2019': 600.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  69: {'ucoa': '1000 - 05106 - 00122 - 10 - 1600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1600.0,
#   'JC': 0.0,
#   'acct-string': '71432806 55111 Transportation',
#   'acct-desc': 'Transportation',
#   'acct-code': '71432806',
#   'Obj': 55111.0,
#   'budget2020': 1800.0,
#   'budget2019': 2671.0,
#   'actual2018': 1175.0,
#   'actual2017': 1175.0},
#  70: {'ucoa': '1000 - 05106 - 00122 - 10 - 1600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1600.0,
#   'JC': 0.0,
#   'acct-string': '71432806 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71432806',
#   'Obj': 56101.0,
#   'budget2020': 2000.0,
#   'budget2019': 1579.0,
#   'actual2018': 2206.9,
#   'actual2017': 1828.45},
#  71: {'ucoa': '1000 - 05106 - 00122 - 10 - 1600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1600.0,
#   'JC': 0.0,
#   'acct-string': '71432806 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71432806',
#   'Obj': 57305.0,
#   'budget2020': 5000.0,
#   'budget2019': 3700.0,
#   'actual2018': 5584.45,
#   'actual2017': 5704.75},
#  72: {'ucoa': '1000 - 05106 - 00122 - 10 - 1600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1600.0,
#   'JC': 0.0,
#   'acct-string': '71432806 57306 Furniture & Fixtures',
#   'acct-desc': 'Furniture & Fixtures',
#   'acct-code': '71432806',
#   'Obj': 57306.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 0.0,
#   'actual2017': 924.31},
#  73: {'ucoa': '1000 - 05106 - 00122 - 10 - 1600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1600.0,
#   'JC': 0.0,
#   'acct-string': '71432806 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71432806',
#   'Obj': 58102.0,
#   'budget2020': 900.0,
#   'budget2019': 900.0,
#   'actual2018': 339.0,
#   'actual2017': 400.0},
#  74: {'ucoa': '1000 - 05106 - 00222 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71441806 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71441806',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 398.4,
#   'actual2018': 0.0,
#   'actual2017': 2125.0},
#  75: {'ucoa': '1000 - 05106 - 00122 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71432906 55111 Transportation',
#   'acct-desc': 'Transportation',
#   'acct-code': '71432906',
#   'Obj': 55111.0,
#   'budget2020': 1000.0,
#   'budget2019': 1065.0,
#   'actual2018': 1460.0,
#   'actual2017': 0.0},
#  76: {'ucoa': '1000 - 05106 - 00122 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71432906 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71432906',
#   'Obj': 55809.0,
#   'budget2020': 300.0,
#   'budget2019': 300.0,
#   'actual2018': 95.46,
#   'actual2017': 0.0},
#  77: {'ucoa': '1000 - 05106 - 00222 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71441806 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71441806',
#   'Obj': 55809.0,
#   'budget2020': 133.6,
#   'budget2019': 133.6,
#   'actual2018': 173.34,
#   'actual2017': 115.56},
#  78: {'ucoa': '1000 - 05106 - 00122 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71432906 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71432906',
#   'Obj': 56101.0,
#   'budget2020': 10000.0,
#   'budget2019': 9600.0,
#   'actual2018': 9296.69,
#   'actual2017': 12573.13},
#  79: {'ucoa': '1000 - 05106 - 00122 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71432906 56401 Textbooks',
#   'acct-desc': 'Textbooks',
#   'acct-code': '71432906',
#   'Obj': 56401.0,
#   'budget2020': 6250.0,
#   'budget2019': 6075.0,
#   'actual2018': 5431.77,
#   'actual2017': 4932.49},
#  80: {'ucoa': '1000 - 05106 - 00122 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71432906 56404 Subscriptions/Periodicals',
#   'acct-desc': 'Subscriptions/Periodicals',
#   'acct-code': '71432906',
#   'Obj': 56404.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 32.0,
#   'actual2017': 0.0},
#  81: {'ucoa': '1000 - 05106 - 00122 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71432906 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71432906',
#   'Obj': 57305.0,
#   'budget2020': 4450.0,
#   'budget2019': 4150.0,
#   'actual2018': 4209.36,
#   'actual2017': 3136.91},
#  82: {'ucoa': '1000 - 05106 - 00122 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71432906 57306 Furniture & Fixtures',
#   'acct-desc': 'Furniture & Fixtures',
#   'acct-code': '71432906',
#   'Obj': 57306.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 712.38,
#   'actual2017': 0.0},
#  83: {'ucoa': '1000 - 05106 - 00122 - 10 - 1700 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1700.0,
#   'JC': 0.0,
#   'acct-string': '71432906 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71432906',
#   'Obj': 58102.0,
#   'budget2020': 570.0,
#   'budget2019': 570.0,
#   'actual2018': 520.99,
#   'actual2017': 25.0},
#  84: {'ucoa': '1000 - 05106 - 00222 - 10 - 1900 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1900.0,
#   'JC': 0.0,
#   'acct-string': '71441906 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71441906',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 275.0,
#   'actual2018': 0.0,
#   'actual2017': 100.0},
#  85: {'ucoa': '1000 - 05106 - 00222 - 10 - 1900 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1900.0,
#   'JC': 0.0,
#   'acct-string': '71441906 53303 Conf/Workshops',
#   'acct-desc': 'Conf/Workshops',
#   'acct-code': '71441906',
#   'Obj': 53303.0,
#   'budget2020': 0.0,
#   'budget2019': 285.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  86: {'ucoa': '1000 - 05106 - 00122 - 10 - 1900 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1900.0,
#   'JC': 0.0,
#   'acct-string': '71433106 55111 Transportation',
#   'acct-desc': 'Transportation',
#   'acct-code': '71433106',
#   'Obj': 55111.0,
#   'budget2020': 1500.0,
#   'budget2019': 1700.0,
#   'actual2018': 1344.86,
#   'actual2017': 1523.5},
#  87: {'ucoa': '1000 - 05106 - 00122 - 10 - 1900 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1900.0,
#   'JC': 0.0,
#   'acct-string': '71433106 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71433106',
#   'Obj': 55809.0,
#   'budget2020': 300.0,
#   'budget2019': 300.0,
#   'actual2018': 90.83,
#   'actual2017': 38.37},
#  88: {'ucoa': '1000 - 05106 - 00222 - 10 - 1900 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 1900.0,
#   'JC': 0.0,
#   'acct-string': '71441906 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71441906',
#   'Obj': 55809.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 120.46,
#   'actual2017': 96.0},
#  89: {'ucoa': '1000 - 05106 - 00122 - 10 - 1900 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1900.0,
#   'JC': 0.0,
#   'acct-string': '71433106 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71433106',
#   'Obj': 56101.0,
#   'budget2020': 500.0,
#   'budget2019': 525.0,
#   'actual2018': 459.74,
#   'actual2017': 0.0},
#  90: {'ucoa': '1000 - 05106 - 00122 - 10 - 1900 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1900.0,
#   'JC': 0.0,
#   'acct-string': '71433106 56401 Textbooks',
#   'acct-desc': 'Textbooks',
#   'acct-code': '71433106',
#   'Obj': 56401.0,
#   'budget2020': 7000.0,
#   'budget2019': 4300.0,
#   'actual2018': 884.19,
#   'actual2017': 0.0},
#  91: {'ucoa': '1000 - 05106 - 00122 - 10 - 1900 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 1900.0,
#   'JC': 0.0,
#   'acct-string': '71433106 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71433106',
#   'Obj': 58102.0,
#   'budget2020': 1000.0,
#   'budget2019': 1000.0,
#   'actual2018': 750.0,
#   'actual2017': 871.0},
#  92: {'ucoa': '1000 - 05106 - 00222 - 10 - 2000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 2000.0,
#   'JC': 0.0,
#   'acct-string': '71443306 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71443306',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 210.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  93: {'ucoa': '1000 - 05106 - 00122 - 10 - 2000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2000.0,
#   'JC': 0.0,
#   'acct-string': '71434006 54311 Maint-Fixturesequip',
#   'acct-desc': 'Maint-Fixturesequip',
#   'acct-code': '71434006',
#   'Obj': 54311.0,
#   'budget2020': 500.0,
#   'budget2019': 500.0,
#   'actual2018': 476.0,
#   'actual2017': 580.0},
#  94: {'ucoa': '1000 - 05106 - 00122 - 10 - 2000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2000.0,
#   'JC': 0.0,
#   'acct-string': '71434006 55111 Transportation',
#   'acct-desc': 'Transportation',
#   'acct-code': '71434006',
#   'Obj': 55111.0,
#   'budget2020': 0.0,
#   'budget2019': 369.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  95: {'ucoa': '1000 - 05106 - 00122 - 10 - 2000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2000.0,
#   'JC': 0.0,
#   'acct-string': '71434006 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71434006',
#   'Obj': 56101.0,
#   'budget2020': 7605.0,
#   'budget2019': 7605.0,
#   'actual2018': 6646.29,
#   'actual2017': 9685.11},
#  96: {'ucoa': '1000 - 05106 - 00122 - 10 - 2000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2000.0,
#   'JC': 0.0,
#   'acct-string': '71434006 56112 Uniform Supplies',
#   'acct-desc': 'Uniform Supplies',
#   'acct-code': '71434006',
#   'Obj': 56112.0,
#   'budget2020': 700.0,
#   'budget2019': 700.0,
#   'actual2018': 690.0,
#   'actual2017': 700.0},
#  97: {'ucoa': '1000 - 05106 - 00122 - 10 - 2000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2000.0,
#   'JC': 0.0,
#   'acct-string': '71434006 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71434006',
#   'Obj': 57305.0,
#   'budget2020': 5700.0,
#   'budget2019': 5700.0,
#   'actual2018': 5615.74,
#   'actual2017': 5175.88},
#  98: {'ucoa': '1000 - 05106 - 00122 - 10 - 2000 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2000.0,
#   'JC': 0.0,
#   'acct-string': '71434006 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71434006',
#   'Obj': 58102.0,
#   'budget2020': 200.0,
#   'budget2019': 200.0,
#   'actual2018': 410.0,
#   'actual2017': 170.0},
#  99: {'ucoa': '1000 - 05106 - 00222 - 10 - 2400 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 2400.0,
#   'JC': 0.0,
#   'acct-string': '71443406 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71443406',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 26.0,
#   'actual2018': 0.0,
#   'actual2017': 448.0},
#  100: {'ucoa': '1000 - 05106 - 00122 - 10 - 2400 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2400.0,
#   'JC': 0.0,
#   'acct-string': '71434106 56101 Gen Supplies / Materials',
#   'acct-desc': 'Gen Supplies / Materials',
#   'acct-code': '71434106',
#   'Obj': 56101.0,
#   'budget2020': 670.0,
#   'budget2019': 670.0,
#   'actual2018': 128.31,
#   'actual2017': 547.28},
#  101: {'ucoa': '1000 - 05106 - 00122 - 10 - 2400 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2400.0,
#   'JC': 0.0,
#   'acct-string': '71434106 56401 Textbooks',
#   'acct-desc': 'Textbooks',
#   'acct-code': '71434106',
#   'Obj': 56401.0,
#   'budget2020': 300.0,
#   'budget2019': 300.0,
#   'actual2018': 298.25,
#   'actual2017': 302.9},
#  102: {'ucoa': '1000 - 05106 - 00122 - 10 - 2400 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2400.0,
#   'JC': 0.0,
#   'acct-string': '71434106 56404 Subscriptions/Periodicals',
#   'acct-desc': 'Subscriptions/Periodicals',
#   'acct-code': '71434106',
#   'Obj': 56404.0,
#   'budget2020': 480.0,
#   'budget2019': 480.0,
#   'actual2018': 371.29,
#   'actual2017': 0.0},
#  103: {'ucoa': '1000 - 05106 - 00122 - 10 - 2400 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2400.0,
#   'JC': 0.0,
#   'acct-string': '71434106 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71434106',
#   'Obj': 57305.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 0.0,
#   'actual2017': 100.46},
#  104: {'ucoa': '1000 - 05106 - 00122 - 10 - 2400 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 122.0,
#   'Prog': 10.0,
#   'Sub': 2400.0,
#   'JC': 0.0,
#   'acct-string': '71434106 57306 Furniture & Fixtures',
#   'acct-desc': 'Furniture & Fixtures',
#   'acct-code': '71434106',
#   'Obj': 57306.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 118.76,
#   'actual2017': 0.0},
#  105: {'ucoa': '1000 - 05106 - 00511 - 10 - 2500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 511.0,
#   'Prog': 10.0,
#   'Sub': 2500.0,
#   'JC': 0.0,
#   'acct-string': '71401106 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71401106',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 476.0,
#   'actual2018': 0.0,
#   'actual2017': 3750.0},
#  106: {'ucoa': '1000 - 05106 - 00216 - 10 - 2500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 216.0,
#   'Prog': 10.0,
#   'Sub': 2500.0,
#   'JC': 0.0,
#   'acct-string': '71270206 53411 Physicians',
#   'acct-desc': 'Physicians',
#   'acct-code': '71270206',
#   'Obj': 53411.0,
#   'budget2020': 2000.0,
#   'budget2019': 2000.0,
#   'actual2018': 2000.0,
#   'actual2017': 2000.0},
#  107: {'ucoa': '1000 - 05106 - 00216 - 10 - 2500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 216.0,
#   'Prog': 10.0,
#   'Sub': 2500.0,
#   'JC': 0.0,
#   'acct-string': '71270206 53412 Dentists',
#   'acct-desc': 'Dentists',
#   'acct-code': '71270206',
#   'Obj': 53412.0,
#   'budget2020': 3000.0,
#   'budget2019': 3000.0,
#   'actual2018': 3000.0,
#   'actual2017': 3082.82},
#  108: {'ucoa': '1000 - 05106 - 00216 - 10 - 2500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 216.0,
#   'Prog': 10.0,
#   'Sub': 2500.0,
#   'JC': 0.0,
#   'acct-string': '71270206 53417 Contracted Nursing Svcs',
#   'acct-desc': 'Contracted Nursing Svcs',
#   'acct-code': '71270206',
#   'Obj': 53417.0,
#   'budget2020': 560.0,
#   'budget2019': 560.0,
#   'actual2018': 6624.6,
#   'actual2017': 812.0},
#  109: {'ucoa': '1000 - 05106 - 00216 - 10 - 2500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 216.0,
#   'Prog': 10.0,
#   'Sub': 2500.0,
#   'JC': 0.0,
#   'acct-string': '71270206 56115 Medical Supplies',
#   'acct-desc': 'Medical Supplies',
#   'acct-code': '71270206',
#   'Obj': 56115.0,
#   'budget2020': 2750.0,
#   'budget2019': 2750.0,
#   'actual2018': 2779.46,
#   'actual2017': 2864.84},
#  110: {'ucoa': '1000 - 05106 - 00216 - 10 - 2500 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 216.0,
#   'Prog': 10.0,
#   'Sub': 2500.0,
#   'JC': 0.0,
#   'acct-string': '71270206 57305 Equipment',
#   'acct-desc': 'Equipment',
#   'acct-code': '71270206',
#   'Obj': 57305.0,
#   'budget2020': 250.0,
#   'budget2019': 250.0,
#   'actual2018': 261.98,
#   'actual2017': 0.0},
#  111: {'ucoa': '1000 - 05106 - 00222 - 10 - 2600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 2600.0,
#   'JC': 0.0,
#   'acct-string': '71443506 53301 Prof Dev Training',
#   'acct-desc': 'Prof Dev Training',
#   'acct-code': '71443506',
#   'Obj': 53301.0,
#   'budget2020': 0.0,
#   'budget2019': 0.0,
#   'actual2018': 219.0,
#   'actual2017': 250.0},
#  112: {'ucoa': '1000 - 05106 - 00222 - 10 - 2600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 2600.0,
#   'JC': 0.0,
#   'acct-string': '71443506 53303 Conf/Workshops',
#   'acct-desc': 'Conf/Workshops',
#   'acct-code': '71443506',
#   'Obj': 53303.0,
#   'budget2020': 0.0,
#   'budget2019': 250.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  113: {'ucoa': '1000 - 05106 - 00222 - 10 - 2600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 222.0,
#   'Prog': 10.0,
#   'Sub': 2600.0,
#   'JC': 0.0,
#   'acct-string': '71443506 55809 Employee Travel -Teachers',
#   'acct-desc': 'Employee Travel -Teachers',
#   'acct-code': '71443506',
#   'Obj': 55809.0,
#   'budget2020': 87.64,
#   'budget2019': 87.64,
#   'actual2018': 0.0,
#   'actual2017': 43.92},
#  114: {'ucoa': '1000 - 05106 - 00212 - 10 - 2600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 212.0,
#   'Prog': 10.0,
#   'Sub': 2600.0,
#   'JC': 0.0,
#   'acct-string': '71246006 56101 Gen Supplies/Materials',
#   'acct-desc': 'Gen Supplies/Materials',
#   'acct-code': '71246006',
#   'Obj': 56101.0,
#   'budget2020': 150.0,
#   'budget2019': 75.0,
#   'actual2018': 0.0,
#   'actual2017': 0.0},
#  115: {'ucoa': '1000 - 05106 - 00212 - 10 - 2600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 212.0,
#   'Prog': 10.0,
#   'Sub': 2600.0,
#   'JC': 0.0,
#   'acct-string': '71246006 56402 Library Books',
#   'acct-desc': 'Library Books',
#   'acct-code': '71246006',
#   'Obj': 56402.0,
#   'budget2020': 5000.0,
#   'budget2019': 0.0,
#   'actual2018': 0.59,
#   'actual2017': 2774.9},
#  116: {'ucoa': '1000 - 05106 - 00212 - 10 - 2600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 212.0,
#   'Prog': 10.0,
#   'Sub': 2600.0,
#   'JC': 0.0,
#   'acct-string': '71246006 56404 Periodicals',
#   'acct-desc': 'Periodicals',
#   'acct-code': '71246006',
#   'Obj': 56404.0,
#   'budget2020': 3200.0,
#   'budget2019': 0.0,
#   'actual2018': 0.0,
#   'actual2017': 3207.01},
#  117: {'ucoa': '1000 - 05106 - 00212 - 10 - 2600 - 0000',
#   'Fund': 10000000.0,
#   'Loc': 5106.0,
#   'Func': 212.0,
#   'Prog': 10.0,
#   'Sub': 2600.0,
#   'JC': 0.0,
#   'acct-string': '71246006 58102 Dues & Fees',
#   'acct-desc': 'Dues & Fees',
#   'acct-code': '71246006',
#   'Obj': 58102.0,
#   'budget2020': 150.0,
#   'budget2019': 100.0,
#   'actual2018': 0.0,
#   'actual2017': 99.0}}
