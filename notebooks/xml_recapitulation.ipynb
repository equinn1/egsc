# %% [markdown]
# ## xml_recapitulation
#
# E. Quinn 7/3/2021
#
# Read the XML recapitulation summary
#
# To do:
#
# Get 2012 photo and update xml file

# %% [markdown]
# ## Import standard python datascience packages

# %%
import sys
import math
import re
import copy
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
# %matplotlib inline

# %%
from datetime import datetime, timedelta, date
from datascience import *
import uuid
import random

# %% [markdown]
# ### Show the directory we are running in

# %%
# !pwd
# Out:
# /home/gquinn/EG/RI_Div_of_Municipal_Finance/notebooks

# %%
# importing element tree
import xml.etree.ElementTree as ET 

# Pass the path of the xml document 
tree = ET.parse('../recapitulation.xml') 

# get the parent tag 
root = tree.getroot() 

# print the root (parent) tag along with its memory location 
print(root)
# Out:
# <Element 'recapitulations' at 0x7f777b7aaea0>

# %% [markdown]
# ### Decode recapitulation xml file

# %%
def get_amt(elem):
    amt = 0.0
    lst = list(elem)
    if (len(lst) > 0):
        for e in lst:
            amt += float(e.text)
    else:
        try:
            amt += float(elem.text)
        except ValueError:
            print('get_amt ValueError ',elem,elem.text)
    return(amt)

# %%
def get_element(year,cat,elem,key,dd):
    elm = None
    if(elem.tag==key):
        if cat not in dd[year].keys():
            dd[year][cat]={}
        if key not in dd[year][cat].keys():
            dd[year][cat][key] = {}
        if 'element' not in dd[year][cat][key].keys():
            dd[year][cat][key]['element'] = {}
        dd[year][cat][key]['element'] = elem
        return
    else:
        elist = list(elem)
        if (len(elist)!=0):
            for el in elist:
                elm = get_element(year,cat,el,key,dd)
    return

# %%
rcd = {}

for recap in root:
    year = int(recap.find('year').text)                       #'year' is always present
    if year not in rcd.keys():
        rcd[year] = {}                                        #year is high level index into dictionary
    valuation_date = recap.find('valuation_date').text        #'valuation_date' is always present
    rcd[year]['valuation_date'] = valuation_date
    cats=['valuation','tax']
    sums = ['real_estate','personal_property','motor_vehicle','commercial_industrial']
    for cat in cats:
        e = recap.find(cat)
        for s in sums:
            elm = get_element(year,cat,e,s,rcd)
            
for year in rcd.keys():
    for cat in cats:
        for s in sums:
            try:
                elem = rcd[year][cat][s]['element']
                amt = get_amt(elem)
                rcd[year][cat][s]['amt'] = amt
            except KeyError:
                continue
                
rcd
# Out:
# {1919: {'valuation_date': '9/19/1919',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b70b4a0>,
#     'amt': 2137200.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b70b270>,
#     'amt': 1057850.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b70b310>,
#     'amt': 38469.6},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b70b4f0>,
#     'amt': 10999.7}}},
#  1920: {'valuation_date': '9/20/1920',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b70b090>,
#     'amt': 2160550.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777bf8ab30>,
#     'amt': 1132210.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777bf8acc0>,
#     'amt': 38889.9},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b70d900>,
#     'amt': 11831.38}}},
#  1921: {'valuation_date': '6/15/1921',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b70d220>,
#     'amt': 2226200.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b70d130>,
#     'amt': 1158650.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b70d310>,
#     'amt': 44524.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b70d400>,
#     'amt': 13679.4}}},
#  1923: {'valuation_date': '6/15/1923',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b70dea0>,
#     'amt': 2519850.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b70d8b0>,
#     'amt': 1778955.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6fc3b0>,
#     'amt': 54176.78},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6fc630>,
#     'amt': 18188.510000000002}}},
#  1924: {'valuation_date': '6/16/1924',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6fa860>,
#     'amt': 2661710.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6fa130>,
#     'amt': 1551630.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6fa2c0>,
#     'amt': 58557.62},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6fa090>,
#     'amt': 18496.920000000002}}},
#  1925: {'valuation_date': '6/15/1925',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6fa770>,
#     'amt': 2937877.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6fa9a0>,
#     'amt': 1617680.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6faae0>,
#     'amt': 58757.54},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6fab30>,
#     'amt': 18277.92}}},
#  1926: {'valuation_date': '6/15/1926',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b705090>,
#     'amt': 3186660.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b705180>,
#     'amt': 1534546.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b7052c0>,
#     'amt': 63733.2},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b705310>,
#     'amt': 17684.04}}},
#  1927: {'valuation_date': '6/15/1927',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b705810>,
#     'amt': 3673985.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b705900>,
#     'amt': 1413327.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b705a40>,
#     'amt': 78990.68},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b705a90>,
#     'amt': 18077.120000000003}}},
#  1928: {'valuation_date': '6/15/1928',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b705f90>,
#     'amt': 3822342.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b7010e0>,
#     'amt': 1378173.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b701220>,
#     'amt': 87352.7},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b701270>,
#     'amt': 18314.29}}},
#  1929: {'valuation_date': '6/15/1929',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b701770>,
#     'amt': 3938046.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b701860>,
#     'amt': 1605190.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b7019a0>,
#     'amt': 90575.06},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b7019f0>,
#     'amt': 22120.84}}},
#  1930: {'valuation_date': '6/16/1930',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b701ef0>,
#     'amt': 3440096.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b690040>,
#     'amt': 1581825.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b690180>,
#     'amt': 96969.5},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6901d0>,
#     'amt': 23213.02}}},
#  1931: {'valuation_date': '6/15/1931',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6906d0>,
#     'amt': 4081511.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6907c0>,
#     'amt': 1561785.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b690900>,
#     'amt': 97956.26},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b690950>,
#     'amt': 23262.48}}},
#  1932: {'valuation_date': '6/15/1932',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b690a90>,
#     'amt': 4150803.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b690b80>,
#     'amt': 1520726.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b690cc0>,
#     'amt': 99619.27},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b690d10>,
#     'amt': 22378.989999999998}}},
#  1933: {'valuation_date': '6/15/1933',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b693270>,
#     'amt': 4183208.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b693360>,
#     'amt': 1364288.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6934a0>,
#     'amt': 100396.99},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6934f0>,
#     'amt': 20637.07}}},
#  1934: {'valuation_date': '6/15/1934',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6939f0>,
#     'amt': 4229688.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b693ae0>,
#     'amt': 1321692.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b693c20>,
#     'amt': 101512.51199999999},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b693d10>,
#     'amt': 20233.908}}},
#  1935: {'valuation_date': '6/15/1935',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b697270>,
#     'amt': 4268570.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b697360>,
#     'amt': 1348905.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6974a0>,
#     'amt': 102445.68},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b697590>,
#     'amt': 20886.02}}},
#  1936: {'valuation_date': '6/15/1936',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b697a90>,
#     'amt': 4341715.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b697b80>,
#     'amt': 1386620.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b697cc0>,
#     'amt': 102030.3},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b697db0>,
#     'amt': 22095.07}}},
#  1937: {'valuation_date': '6/15/1937',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b69b310>,
#     'amt': 4398060.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b69b400>,
#     'amt': 1417110.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b69b540>,
#     'amt': 103354.41},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b69b630>,
#     'amt': 3929.7799999999997}}},
#  1938: {'valuation_date': '6/15/1938',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b69bb80>,
#     'amt': 4437315.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b69bc70>,
#     'amt': 1172840.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b69bdb0>,
#     'amt': 106495.56},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b69bea0>,
#     'amt': 21865.36}}},
#  1939: {'valuation_date': '6/15/1939',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b69f450>,
#     'amt': 4469300.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b69f540>,
#     'amt': 1295195.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b69f680>,
#     'amt': 107253.2},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b69f770>,
#     'amt': 22073.18}}},
#  1940: {'valuation_date': '6/15/1940',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b69fcc0>,
#     'amt': 4495245.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b69fdb0>,
#     'amt': 1304015.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b69fef0>,
#     'amt': 107885.88},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6a3040>,
#     'amt': 22733.3}}},
#  1941: {'valuation_date': '6/16/1941',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6a3590>,
#     'amt': 4479250.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6a3680>,
#     'amt': 1396035.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6a37c0>,
#     'amt': 107502.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6a38b0>,
#     'amt': 25706.140000000003}}},
#  1942: {'valuation_date': '6/15/1942',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6a3e00>,
#     'amt': 4563205.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6a3ef0>,
#     'amt': 1296220.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6a6090>,
#     'amt': 109516.92},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6a6180>,
#     'amt': 24708.48}}},
#  1943: {'valuation_date': '6/15/1943',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6a66d0>,
#     'amt': 4573838.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6a67c0>,
#     'amt': 1197316.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6a6900>,
#     'amt': 114345.95},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6a69f0>,
#     'amt': 23822.11}}},
#  1944: {'valuation_date': '6/15/1944',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6a6f40>,
#     'amt': 4611104.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6ab090>,
#     'amt': 1355435.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6ab1d0>,
#     'amt': 115457.6},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6ab2c0>,
#     'amt': 25482.2}}},
#  1945: {'valuation_date': '6/15/1945',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6ab810>,
#     'amt': 5204080.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6ab900>,
#     'amt': 1459970.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6aba40>,
#     'amt': 122298.23},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6abb30>,
#     'amt': 26404.97}}},
#  1946: {'valuation_date': '6/15/1946',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6af0e0>,
#     'amt': 5256340.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6af1d0>,
#     'amt': 1545230.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6af310>,
#     'amt': 123523.99},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6af400>,
#     'amt': 28451.48}}},
#  1947: {'valuation_date': '6/16/1947',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6af950>,
#     'amt': 5721100.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6afa40>,
#     'amt': 1738690.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6afb80>,
#     'amt': 134445.85},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6afc70>,
#     'amt': 33988.39}}},
#  1948: {'valuation_date': '6/15/1948',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6b2220>,
#     'amt': 5849420.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6b2310>,
#     'amt': 1878260.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6b2450>,
#     'amt': 137461.37},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6b2540>,
#     'amt': 38280.92}}},
#  1949: {'valuation_date': '6/15/1949',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6b2a90>,
#     'amt': 6060340.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6b2b80>,
#     'amt': 2094790.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6b2cc0>,
#     'amt': 142417.99},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6b2db0>,
#     'amt': 43078.24}}},
#  1950: {'valuation_date': '6/15/1950',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6b6360>,
#     'amt': 6311040.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6b6450>,
#     'amt': 2563560.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6b6590>,
#     'amt': 148309.44},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6b6680>,
#     'amt': 50530.32}}},
#  1951: {'valuation_date': '12/31/1950',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6b6bd0>,
#     'amt': 6733430.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6b6cc0>,
#     'amt': 2894277.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6b6e00>,
#     'amt': 168335.75},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6b6ef0>,
#     'amt': 62481.15}}},
#  1952: {'valuation_date': '12/31/1951',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6bb4a0>,
#     'amt': 10444420.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6bb590>,
#     'amt': 3240470.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6bb6d0>,
#     'amt': 198443.98},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6bb7c0>,
#     'amt': 54473.93}}},
#  1953: {'valuation_date': '12/31/1952',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6bbd10>,
#     'amt': 11092980.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6bbe00>,
#     'amt': 3462780.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6bbf40>,
#     'amt': 210766.62},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6be090>,
#     'amt': 58389.57}}},
#  1954: {'valuation_date': '12/31/1953',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6be5e0>,
#     'amt': 11436900.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6be6d0>,
#     'amt': 3157160.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6be810>,
#     'amt': 217301.1},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6be900>,
#     'amt': 53678.69}}},
#  1955: {'valuation_date': '12/31/1954',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6bee50>,
#     'amt': 11874920.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6bef40>,
#     'amt': 3088370.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6c20e0>,
#     'amt': 290935.54000000004},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6c21d0>,
#     'amt': 66236.87}}},
#  1956: {'valuation_date': '12/31/1955',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6c2720>,
#     'amt': 12402880.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6c2810>,
#     'amt': 3626120.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6c2950>,
#     'amt': 316273.44},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6c2a40>,
#     'amt': 77640.09000000001}}},
#  1957: {'valuation_date': '12/31/1956',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6c2f90>,
#     'amt': 13110380.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6c50e0>,
#     'amt': 3842530.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6c5220>,
#     'amt': 360535.44999999995},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6c5310>,
#     'amt': 91915.26000000001}}},
#  1958: {'valuation_date': '12/31/1957',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6c5860>,
#     'amt': 13726360.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6c5950>,
#     'amt': 5072230.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6c5a90>,
#     'amt': 343159.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6c5b80>,
#     'amt': 128545.0}}},
#  1959: {'valuation_date': '12/31/1958',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6ca130>,
#     'amt': 14149010.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6ca220>,
#     'amt': 5536020.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6ca360>,
#     'amt': 403246.79000000004},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6ca450>,
#     'amt': 145107.37}}},
#  1960: {'valuation_date': '12/31/1959',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6ca9a0>,
#     'amt': 15231780.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6caa90>,
#     'amt': 6278042.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6cabd0>,
#     'amt': 456953.39999999997},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6cacc0>,
#     'amt': 164516.1}}},
#  1961: {'valuation_date': '12/31/1960',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6ce270>,
#     'amt': 16458930.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6ce360>,
#     'amt': 6514900.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6ce4a0>,
#     'amt': 493767.9},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6ce590>,
#     'amt': 166860.15999999997}}},
#  1962: {'valuation_date': '12/31/1961',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6ceae0>,
#     'amt': 17726740.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6cebd0>,
#     'amt': 5719600.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6ced10>,
#     'amt': 611565.53},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6cee00>,
#     'amt': 166214.98}}},
#  1963: {'valuation_date': '12/31/1962',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6513b0>,
#     'amt': 19288930.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6514a0>,
#     'amt': 7142550.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6515e0>,
#     'amt': 675112.55},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6516d0>,
#     'amt': 217404.22}}},
#  1964: {'valuation_date': '12/31/1963',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b651c20>,
#     'amt': 20468140.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b651d10>,
#     'amt': 7808940.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b651e50>,
#     'amt': 777789.32},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b651f40>,
#     'amt': 252442.48}}},
#  1965: {'valuation_date': '12/31/1964',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6554f0>,
#     'amt': 42275320.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6555e0>,
#     'amt': 10672360.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b655720>,
#     'amt': 1099158.32},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b655810>,
#     'amt': 247769.48}}},
#  1966: {'valuation_date': '12/31/1965',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b655d60>,
#     'amt': 47915720.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b655e50>,
#     'amt': 10984960.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b655f90>,
#     'amt': 1245808.72},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b65a0e0>,
#     'amt': 259723.32}}},
#  1967: {'valuation_date': '12/31/1966',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b65a630>,
#     'amt': 49880340.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b65a720>,
#     'amt': 11171540.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b65a860>,
#     'amt': 1546290.5399999998},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b65a950>,
#     'amt': 317952.08}}},
#  1968: {'valuation_date': '12/31/1967',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b65aea0>,
#     'amt': 51544840.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b65af90>,
#     'amt': 12154220.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b65d130>,
#     'amt': 1597890.04},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b65d220>,
#     'amt': 337618.4}}},
#  1969: {'valuation_date': '12/31/1968',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b65d770>,
#     'amt': 52328080.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b65d860>,
#     'amt': 8681640.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b65d9a0>,
#     'amt': 1839818.7599999998},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b65da90>,
#     'amt': 331579.16}}},
#  1970: {'valuation_date': '12/31/1969',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b661040>,
#     'amt': 52836940.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b661130>,
#     'amt': 9256600.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b661270>,
#     'amt': 2028937.92},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b661360>,
#     'amt': 385946.28}}},
#  1971: {'valuation_date': '12/31/1970',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6618b0>,
#     'amt': 55493780.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6619a0>,
#     'amt': 10645320.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b661ae0>,
#     'amt': 2197564.3899999997},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b661bd0>,
#     'amt': 430393.24}}},
#  1972: {'valuation_date': '12/31/1971',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b666180>,
#     'amt': 57503460.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b666270>,
#     'amt': 3935140.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6662c0>,
#     'amt': 5035880.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b666360>,
#     'amt': 2275700.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b666400>,
#     'amt': 2369142.55},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6664f0>,
#     'amt': 162177.77},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b666540>,
#     'amt': 207478.26},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b666590>,
#     'amt': 96671.74}}},
#  1973: {'valuation_date': '12/31/1972',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b666a40>,
#     'amt': 61594250.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b666b30>,
#     'amt': 4244460.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b666b80>,
#     'amt': 5668120.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b666bd0>,
#     'amt': 2270800.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b666c70>,
#     'amt': 2759422.52},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b666d60>,
#     'amt': 191151.84},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b666db0>,
#     'amt': 253934.21},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b666e00>,
#     'amt': 99688.12}}},
#  1974: {'valuation_date': '12/31/1973',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b669310>,
#     'amt': 64903180.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b669400>,
#     'amt': 4809120.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b669450>,
#     'amt': 6712160.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b6694a0>,
#     'amt': 2281340.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b669540>,
#     'amt': 3108861.42},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b669630>,
#     'amt': 230356.71},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b669680>,
#     'amt': 321507.44},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b6696d0>,
#     'amt': 90112.93}}},
#  1975: {'valuation_date': '12/31/1974',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b669b80>,
#     'amt': 67678700.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b669c70>,
#     'amt': 4977180.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b669cc0>,
#     'amt': 8027020.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b669d10>,
#     'amt': 2281340.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b669db0>,
#     'amt': 3370398.5900000003},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b669ea0>,
#     'amt': 247863.62},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b669ef0>,
#     'amt': 399746.54},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b669f40>,
#     'amt': 80120.66}}},
#  1976: {'valuation_date': '12/31/1975',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b66d450>,
#     'amt': 169771170.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b66d540>,
#     'amt': 8831660.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b66d590>,
#     'amt': 11653770.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b66d5e0>,
#     'amt': 2402340.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b66d680>,
#     'amt': 4023572.3},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b66d770>,
#     'amt': 209310.46},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b66d7c0>,
#     'amt': 276192.74},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b66d810>,
#     'amt': 73788.77}}},
#  1977: {'valuation_date': '12/31/1976',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b66dcc0>,
#     'amt': 174042830.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b66ddb0>,
#     'amt': 8669070.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b66de00>,
#     'amt': 10393240.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b66de50>,
#     'amt': 2039570.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b66def0>,
#     'amt': 4571252.33},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b670040>,
#     'amt': 227563.72},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b670090>,
#     'amt': 272831.67},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b6700e0>,
#     'amt': 53722.67}}},
#  1978: {'valuation_date': '12/31/1977',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b670590>,
#     'amt': 181478650.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b670680>,
#     'amt': 8921620.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6706d0>,
#     'amt': 12131220.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b670720>,
#     'amt': 2257500.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6707c0>,
#     'amt': 4881776.17},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6708b0>,
#     'amt': 239991.76},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b670900>,
#     'amt': 326328.33},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b670950>,
#     'amt': 49552.13}}},
#  1979: {'valuation_date': '12/31/1978',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b670e00>,
#     'amt': 188266310.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b670ef0>,
#     'amt': 8979970.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b670f40>,
#     'amt': 12522570.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b670f90>,
#     'amt': 2257500.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b674090>,
#     'amt': 5309109.02},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b674180>,
#     'amt': 253235.06},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6741d0>,
#     'amt': 353137.49},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b674220>,
#     'amt': 39641.7}}},
#  1980: {'valuation_date': '12/31/1979',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6746d0>,
#     'amt': 193200460.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6747c0>,
#     'amt': 9400430.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b674810>,
#     'amt': 13882280.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b674860>,
#     'amt': 2257500.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b674900>,
#     'amt': 5989214.260000001},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6749f0>,
#     'amt': 291413.33},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b674a40>,
#     'amt': 430350.68},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b674a90>,
#     'amt': 29731.27}}},
#  1981: {'valuation_date': '12/31/1980',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b674f90>,
#     'amt': 199521730.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6780e0>,
#     'amt': 9367110.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b678130>,
#     'amt': 16448640.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b678180>,
#     'amt': 2249520.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b678220>,
#     'amt': 6584283.09},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b678310>,
#     'amt': 309114.63},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b678360>,
#     'amt': 542805.12},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b6783b0>,
#     'amt': 19750.18}}},
#  1982: {'valuation_date': '12/31/1981',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6788b0>,
#     'amt': 203312680.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6789a0>,
#     'amt': 9542880.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6789f0>,
#     'amt': 18364630.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b678a40>,
#     'amt': 2205800.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b678ae0>,
#     'amt': 6912631.12},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b678bd0>,
#     'amt': 324457.92},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b678c20>,
#     'amt': 624397.42},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b678c70>,
#     'amt': 9683.46}}},
#  1983: {'valuation_date': '12/31/1982',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b67c1d0>,
#     'amt': 206518140.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b67c2c0>,
#     'amt': 10698260.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b67c310>,
#     'amt': 20656420.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b67c360>,
#     'amt': 2205800.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b67c400>,
#     'amt': 7536817.11},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b67c4f0>,
#     'amt': 390486.49},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b67c540>,
#     'amt': 753959.33},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b67c590>,
#     'amt': 9683.46}}},
#  1984: {'valuation_date': '12/31/1983',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b67ca90>,
#     'amt': 210328940.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b67cb80>,
#     'amt': 10707840.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b67cbd0>,
#     'amt': 21624320.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b67cc20>,
#     'amt': 2205800.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b67ccc0>,
#     'amt': 8055598.4},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b67cdb0>,
#     'amt': 410110.27},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b67ce00>,
#     'amt': 828211.47},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b67ce50>,
#     'amt': 4852.77}}},
#  1985: {'valuation_date': '12/31/1984',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b67f3b0>,
#     'amt': 215155920.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b67f4a0>,
#     'amt': 11075610.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b67f4f0>,
#     'amt': 23963970.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b67f590>,
#     'amt': 8305018.52},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b67f680>,
#     'amt': 427518.6},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b67f6d0>,
#     'amt': 925011.21}}},
#  1986: {'valuation_date': '12/31/1985',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b67fb80>,
#     'amt': 499803492.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b67fc70>,
#     'amt': 20941989.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b67fcc0>,
#     'amt': 26289450.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b67fd60>,
#     'amt': 9571246.55},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b67fe50>,
#     'amt': 401040.31},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b67fea0>,
#     'amt': 503446.01}}},
#  1987: {'valuation_date': '12/31/1986',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6833b0>,
#     'amt': 526239442.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6834a0>,
#     'amt': 21954770.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6834f0>,
#     'amt': 37633880.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b683590>,
#     'amt': 10577351.04},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b683680>,
#     'amt': 441280.2},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6836d0>,
#     'amt': 756275.6}}},
#  1988: {'valuation_date': '12/31/1987',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b683b80>,
#     'amt': 552304106.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b683c70>,
#     'amt': 24115050.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b683cc0>,
#     'amt': 42059965.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b683d60>,
#     'amt': 10577351.04},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b683e50>,
#     'amt': 522323.28},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b683ea0>,
#     'amt': 910854.84}}},
#  1989: {'valuation_date': '12/31/1988',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6873b0>,
#     'amt': 572851264.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6874a0>,
#     'amt': 24987195.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6874f0>,
#     'amt': 51205330.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b687590>,
#     'amt': 13473395.04},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b687680>,
#     'amt': 587692.16},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6876d0>,
#     'amt': 1204161.66}}},
#  1990: {'valuation_date': '12/31/1989',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b687b80>,
#     'amt': 586946732.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b687c70>,
#     'amt': 24597347.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b687cc0>,
#     'amt': 56547730.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b687d60>,
#     'amt': 14121872.72},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b687e50>,
#     'amt': 600464.52},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b687ea0>,
#     'amt': 1360345.32}}},
#  1991: {'valuation_date': '12/31/1990',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b68b3b0>,
#     'amt': 602739440.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b68b4a0>,
#     'amt': 29680711.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b68b4f0>,
#     'amt': 57890557.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b68b590>,
#     'amt': 14947936.36},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b68b680>,
#     'amt': 736076.16},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b68b6d0>,
#     'amt': 1435531.8}}},
#  1992: {'valuation_date': '12/31/1991',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b68bb80>,
#     'amt': 611202900.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b68bbd0>,
#     'amt': 30947107.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b68bc20>,
#     'amt': 56846426.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b68bcc0>,
#     'amt': 15524509.18},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b68bd10>,
#     'amt': 786049.12},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b68bd60>,
#     'amt': 1444170.08}}},
#  1993: {'valuation_date': '12/31/1992',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b68e270>,
#     'amt': 618162720.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b68e2c0>,
#     'amt': 31813015.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b68e310>,
#     'amt': 62079038.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b68e3b0>,
#     'amt': 16535795.32},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b68e400>,
#     'amt': 850989.52},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b68e450>,
#     'amt': 1660867.2}}},
#  1994: {'valuation_date': '12/31/1993',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b68e900>,
#     'amt': 626396062.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b68e950>,
#     'amt': 32098832.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b68e9a0>,
#     'amt': 70619312.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b68ea40>,
#     'amt': 17463868.6},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b68ea90>,
#     'amt': 894907.4},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b68eae0>,
#     'amt': 1968679.52}}},
#  1995: {'valuation_date': '12/31/1994',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b68ef90>,
#     'amt': 638992182.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b612040>,
#     'amt': 34840975.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b612090>,
#     'amt': 73089949.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b612130>,
#     'amt': 18287956.25},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b612180>,
#     'amt': 997148.71},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6121d0>,
#     'amt': 2091883.8}}},
#  1996: {'valuation_date': '12/31/1995',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b612680>,
#     'amt': 862026490.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6126d0>,
#     'amt': 41138770.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b612720>,
#     'amt': 79941367.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6127c0>,
#     'amt': 19093886.76},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b612810>,
#     'amt': 911223.76},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b612860>,
#     'amt': 1770701.28}}},
#  1997: {'valuation_date': '12/31/1996',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b612d10>,
#     'amt': 872761780.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b612d60>,
#     'amt': 38477850.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b612db0>,
#     'amt': 83646214.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b612e50>,
#     'amt': 19968789.53},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b612ea0>,
#     'amt': 880373.21},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b612ef0>,
#     'amt': 1913825.38}}},
#  1998: {'valuation_date': '12/31/1997',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b616400>,
#     'amt': 891946000.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b616450>,
#     'amt': 38381860.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6164a0>,
#     'amt': 90493465.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b616540>,
#     'amt': 21139120.2},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6165e0>,
#     'amt': 909650.08},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b616630>,
#     'amt': 2144695.12}}},
#  1999: {'valuation_date': '12/31/1998',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b616ae0>,
#     'amt': 905128200.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b616b30>,
#     'amt': 30778460.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b616b80>,
#     'amt': 104626318.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b616bd0>,
#     'amt': 8105230.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b616d10>,
#     'amt': 22483384.49},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b616d60>,
#     'amt': 764536.95},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b616db0>,
#     'amt': 2393850.16},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b616e00>,
#     'amt': 172884.56}}},
#  2000: {'valuation_date': '12/31/1999',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b61a770>,
#     'amt': 907221877.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b61a860>,
#     'amt': 33102930.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b61a8b0>,
#     'amt': 85002642.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b61a900>,
#     'amt': 7541720.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b61a9f0>,
#     'amt': 24304474.080000002},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b61aae0>,
#     'amt': 886827.49},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b61ab30>,
#     'amt': 1945969.55},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b61ac20>,
#     'amt': 142991.01}}},
#  2001: {'valuation_date': '12/31/2000',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b61d4a0>,
#     'amt': 926948502.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b61d590>,
#     'amt': 31439320.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b61d5e0>,
#     'amt': 84425596.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b61d630>,
#     'amt': 7640180.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b61d720>,
#     'amt': 25570386.69},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b61d810>,
#     'amt': 867410.83},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b61d860>,
#     'amt': 1930804.2999999998},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b61d950>,
#     'amt': 126750.58}}},
#  2002: {'valuation_date': '12/31/2001',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b621220>,
#     'amt': 952035031.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b621310>,
#     'amt': 34512380.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b621360>,
#     'amt': 77494487.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b6213b0>,
#     'amt': 7766390.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6214a0>,
#     'amt': 26253016.15},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b621590>,
#     'amt': 867410.83},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6215e0>,
#     'amt': 1772334.9000000001},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b6216d0>,
#     'amt': 110438.07}}},
#  2003: {'valuation_date': '12/31/2002',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b621ea0>,
#     'amt': 1656109702.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b621ef0>,
#     'amt': 40434805.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b621f40>,
#     'amt': 81839413.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b621f90>,
#     'amt': 7723685.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6260e0>,
#     'amt': 28383952.32},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b626130>,
#     'amt': 693052.76},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b626180>,
#     'amt': 1871633.91},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b6261d0>,
#     'amt': 86193.45}}},
#  2004: {'valuation_date': '12/31/2003',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6269f0>,
#     'amt': 1683951227.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b626a40>,
#     'amt': 37354774.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b626a90>,
#     'amt': 80369596.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b626ae0>,
#     'amt': 8003705.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b626bd0>,
#     'amt': 30159566.48},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b626c20>,
#     'amt': 669024.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b626c70>,
#     'amt': 1837442.82},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b626d60>,
#     'amt': 86193.45}}},
#  2005: {'valuation_date': '12/31/2004',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b62a680>,
#     'amt': 1737620143.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b62a770>,
#     'amt': 40474098.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b62a7c0>,
#     'amt': 89021674.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b62a810>,
#     'amt': 9380440.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b62a900>,
#     'amt': 31841937.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b62a9f0>,
#     'amt': 741890.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b62aa40>,
#     'amt': 2035461.01},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b62ab30>,
#     'amt': 66695.0}}},
#  2006: {'valuation_date': '12/31/2005',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b62d400>,
#     'amt': 2539740259.68},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b62d4f0>,
#     'amt': 54602756.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b62d540>,
#     'amt': 84815483.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b62d590>,
#     'amt': 8455038.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b62d680>,
#     'amt': 32626885.22},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b62d770>,
#     'amt': 702191.44},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b62d7c0>,
#     'amt': 1939443.23},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b62d8b0>,
#     'amt': 40076.88}}},
#  2007: {'valuation_date': '12/31/2006',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b631310>,
#     'amt': 2585886751.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b631450>,
#     'amt': 57184122.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b631540>,
#     'amt': 83579738.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b631590>,
#     'amt': 8455038.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b631680>,
#     'amt': 35012906.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b631770>,
#     'amt': 774273.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b631860>,
#     'amt': 1914418.0},
#    'commercial_industrial': {'element': <Element 'commercial_industrial' at 0x7f777b631950>,
#     'amt': 25640.0}}},
#  2008: {'valuation_date': '12/31/2007',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b636400>,
#     'amt': 2619904759.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b636540>,
#     'amt': 60688733.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b636630>,
#     'amt': 89514879.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6366d0>,
#     'amt': 36678666.61},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b636810>,
#     'amt': 849642.26},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b636900>,
#     'amt': 2047409.99}}},
#  2009: {'valuation_date': '12/31/2008',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b63a270>,
#     'amt': 2324711170.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b63a2c0>,
#     'amt': 66899328.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b63a310>,
#     'amt': 75522116.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b63a3b0>,
#     'amt': 38683193.8},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b63a400>,
#     'amt': 1113204.9},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b63a450>,
#     'amt': 1727945.72}}},
#  2010: {'valuation_date': '12/31/2009',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b63aa90>,
#     'amt': 2332584161.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b63aae0>,
#     'amt': 58847704.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b63ab30>,
#     'amt': 82775361.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b63abd0>,
#     'amt': 40237076.78},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b63ac20>,
#     'amt': 1015122.89},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b63ac70>,
#     'amt': 1893900.26}}},
#  2011: {'valuation_date': '12/31/2010',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b63d360>,
#     'amt': 2144115810.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b63d3b0>,
#     'amt': 57844397.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b63d400>,
#     'amt': 87666316.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b63d4a0>,
#     'amt': 40998655.48},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b63d4f0>,
#     'amt': 1011698.5},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b63d540>,
#     'amt': 2005805.31}}},
#  2012: {'valuation_date': '12/31/2011',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b63db80>,
#     'amt': 2081640557.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b63dbd0>,
#     'amt': 61910482.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b63dc70>,
#     'amt': 40998655.48},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b63dcc0>,
#     'amt': 1011698.5},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b63dd10>,
#     'amt': 2005805.31}}},
#  2013: {'valuation_date': '12/31/2012',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6423b0>,
#     'amt': 2132786050.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b642400>,
#     'amt': 67260089.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b642450>,
#     'amt': 94961748.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6424f0>,
#     'amt': 49608603.52},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b642540>,
#     'amt': 1564469.67},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b642590>,
#     'amt': 2172724.79}}},
#  2014: {'valuation_date': '12/31/2013',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b642c20>,
#     'amt': 2132786050.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b642c70>,
#     'amt': 67260089.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b642cc0>,
#     'amt': 94961748.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b642d60>,
#     'amt': 49608603.52},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b642db0>,
#     'amt': 1564469.67},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b642e00>,
#     'amt': 2172724.79}}},
#  2015: {'valuation_date': '12/31/2014',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6454f0>,
#     'amt': 2174003472.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b645540>,
#     'amt': 74162119.0},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b645590>,
#     'amt': 96484822.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b645630>,
#     'amt': 51480402.22},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b645680>,
#     'amt': 1756158.98},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b6456d0>,
#     'amt': 2207572.73}}},
#  2016: {'valuation_date': '12/31/2015',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b645d60>,
#     'amt': 2194388169.35},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b645db0>,
#     'amt': 77218680.67},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b645e00>,
#     'amt': 100367144.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b645ea0>,
#     'amt': 52862811.0},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b645ef0>,
#     'amt': 1860198.02},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b645f40>,
#     'amt': 2296766.03}}},
#  2017: {'valuation_date': '12/31/2016',
#   'valuation': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b649680>,
#     'amt': 2206494214.81},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b6496d0>,
#     'amt': 77454333.92},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b649720>,
#     'amt': 93168201.0}},
#   'tax': {'real_estate': {'element': <Element 'real_estate' at 0x7f777b6497c0>,
#     'amt': 52205653.12},
#    'personal_property': {'element': <Element 'personal_property' at 0x7f777b649810>,
#     'amt': 1832569.64},
#    'motor_vehicle': {'element': <Element 'motor_vehicle' at 0x7f777b649860>,
#     'amt': 2131973.42}}}}

# %%
cols = {1:sums[0],2:sums[1],3:sums[2],4:sums[3]}
catcols = {1:cats[0],2:cats[1]}

current_date = date.today()
fname = '../EG_valuation_and_tax_history_' + str(current_date.month) + '_' + \
    str(current_date.day) + '_' + str(current_date.year) + '.csv'

file1 = open(fname,'w')

hstr = '"Year","Valuation Date","Real Estate Valuation","Real Estate Tax","Personal Property Valuation"'\
    + ',"Personal Property Tax","Motor Vehicle Valuation","Motor Vehicle Tax"'\
    + ',"Commercial Valuation","Commercial Tax"\n'
file1.write(hstr)

for year in sorted(rcd.keys()):
    
    hstr = '"' + str(year) + '","' + rcd[year]['valuation_date'] + '"'
    for s in sorted(cols.keys()):
        for cat in sorted(catcols.keys()):
            try:
                amt = str(round(rcd[year][catcols[cat]][cols[s]]['amt'],2))
            except KeyError:
                amt = ''
            hstr += ',' + amt
    file1.write(hstr + '\n')
    
file1.close()
